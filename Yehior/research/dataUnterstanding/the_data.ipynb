# %% [markdown]
# # Heat Cube

# %%
import scipy.io

# Datei laden
data = scipy.io.loadmat("L_0001_heatcube.mat")

# Alle enthaltenen Variablennamen anzeigen

print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'S'])

# %%
HSI = data['S']
print("Shape:", HSI.shape)
print("Dtype:", HSI.dtype)
print("Min:", HSI.min(), "Max:", HSI.max())
# Out:
# Shape: (1080, 1920, 54)
# Dtype: float32
# Min: 0.032958984 Max: 0.20996094

# %%
import matplotlib.pyplot as plt

band_index = 9
plt.imshow(HSI[:, :, band_index], cmap='inferno')
plt.title(f"Hyperspektralbild Band {band_index}")
plt.colorbar(label="Intensität")
plt.axis('off')
plt.show()

# %% [markdown]
# # Materialbibliothek

# %%
import scipy.io

# Datei laden
lib_data = scipy.io.loadmat("matLib_SyntheticScenes.mat")

# Alle enthaltenen Variablennamen anzeigen

print(lib_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'tmp'])

# %%
HSI = lib_data['tmp']
print("Shape:", HSI.shape)
print("Dtype:", HSI.dtype)
print("Min:", HSI.min(), "Max:", HSI.max())
# Out:
# Shape: (54, 28)
# Dtype: float64
# Min: 0.01319124 Max: 0.9928823755729472

# %% [markdown]
# # Wellenzahlen

# %%
import scipy.io

# Datei laden
wave_data = scipy.io.loadmat("wavenumber_SyntheticScenes.mat")

# Alle enthaltenen Variablennamen anzeigen

print(wave_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'nu'])

# %%
HSI = wave_data['nu']
print("Shape:", HSI.shape)
print("Dtype:", HSI.dtype)
print("Min:", HSI.min(), "Max:", HSI.max())
# Out:
# Shape: (54, 1)
# Dtype: uint16
# Min: 720 Max: 1250

# %%
HSI
# Out:
# array([[ 720],
#        [ 730],
#        [ 740],
#        [ 750],
#        [ 760],
#        [ 770],
#        [ 780],
#        [ 790],
#        [ 800],
#        [ 810],
#        [ 820],
#        [ 830],
#        [ 840],
#        [ 850],
#        [ 860],
#        [ 870],
#        [ 880],
#        [ 890],
#        [ 900],
#        [ 910],
#        [ 920],
#        [ 930],
#        [ 940],
#        [ 950],
#        [ 960],
#        [ 970],
#        [ 980],
#        [ 990],
#        [1000],
#        [1010],
#        [1020],
#        [1030],
#        [1040],
#        [1050],
#        [1060],
#        [1070],
#        [1080],
#        [1090],
#        [1100],
#        [1110],
#        [1120],
#        [1130],
#        [1140],
#        [1150],
#        [1160],
#        [1170],
#        [1180],
#        [1190],
#        [1200],
#        [1210],
#        [1220],
#        [1230],
#        [1240],
#        [1250]], dtype=uint16)
